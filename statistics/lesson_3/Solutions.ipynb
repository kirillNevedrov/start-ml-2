# %%
from sklearn.datasets import fetch_california_housing

data = fetch_california_housing(as_frame=True, return_X_y=True)
df, target = data[0], data[1]
# Out:
# C:\Users\Kirill\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Kirill\anaconda3\lib\site-packages\numpy\.libs\libopenblas.4SP5SUA7CBGXUEOC35YP2ASOICYYEQZZ.gfortran-win_amd64.dll
# C:\Users\Kirill\anaconda3\lib\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
target
# Out:
# 0        4.526
# 1        3.585
# 2        3.521
# 3        3.413
# 4        3.422
#          ...
# 20635    0.781
# 20636    0.771
# 20637    0.923
# 20638    0.847
# 20639    0.894
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.histplot(df.MedInc, bins=30)
# Out:
# <AxesSubplot:xlabel='MedInc', ylabel='Count'>

# %%
sns.histplot(df.HouseAge, bins=30)
# Out:
# <AxesSubplot:xlabel='HouseAge', ylabel='Count'>

# %%
3.870671 - 3.534800
# Out:
# 0.33587100000000003

# %%
(28.639486 - 29.000000) / 5
# Out:
# -0.07210279999999969

# %%
target.describe()
# Out:
# count    20640.000000
# mean         2.068558
# std          1.153956
# min          0.149990
# 25%          1.196000
# 50%          1.797000
# 75%          2.647250
# max          5.000010
# Name: MedHouseVal, dtype: float64

# %%
sns.histplot(target, bins=30)
# Out:
# <AxesSubplot:xlabel='MedHouseVal', ylabel='Count'>

# %%
2.647250 - 1.196000
# Out:
# 1.4512500000000002

# %%
df.describe().loc['50%'].sort_values(ascending=False)
# Out:
# Population    1166.000000
# Latitude        34.260000
# HouseAge        29.000000
# AveRooms         5.229129
# MedInc           3.534800
# AveOccup         2.818116
# AveBedrms        1.048780
# Longitude     -118.490000
# Name: 50%, dtype: float64

# %%
import pandas as pd

pd.concat([df, target], axis=1).corr(method='pearson').MedHouseVal.abs().sort_values(ascending=False)
# Out:
# MedHouseVal    1.000000
# MedInc         0.688075
# AveRooms       0.151948
# Latitude       0.144160
# HouseAge       0.105623
# AveBedrms      0.046701
# Longitude      0.045967
# Population     0.024650
# AveOccup       0.023737
# Name: MedHouseVal, dtype: float64

# %%
old_df = pd.concat([df, target], axis=1)
new_df = pd.concat([df, target], axis=1)
new_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
description = new_df.describe()
description
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
for c in new_df.columns:
    new_df[c] = (new_df[c] - description[c].loc['mean']) / description[c].loc['std'] 
new_df
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 0      2.344709  0.982119  0.628544  -0.153754   -0.974405 -0.049595
# 1      2.332181 -0.607004  0.327033  -0.263329    0.861418 -0.092510
# 2      1.782656  1.856137  1.155592  -0.049015   -0.820757 -0.025842
# 3      0.932945  1.856137  0.156962  -0.049832   -0.766010 -0.050328
# 4     -0.012881  1.856137  0.344702  -0.032905   -0.759828 -0.085614
# ...         ...       ...       ...        ...         ...       ...
# 20635 -1.216099 -0.289180 -0.155020   0.077352   -0.512579 -0.049109
# 20636 -0.691576 -0.845373  0.276874   0.462353   -0.944382  0.005021
# 20637 -1.142566 -0.924829 -0.090316   0.049413   -0.369528 -0.071733
# 20638 -1.054557 -0.845373 -0.040210   0.158774   -0.604415 -0.091223
# 20639 -0.780111 -1.004285 -0.070441   0.138399   -0.033976 -0.043681
#
#        Latitude  Longitude  MedHouseVal
# 0      1.052523  -1.327803     2.129580
# 1      1.043159  -1.322812     1.314124
# ...

# %%
old_df.corr(method='pearson')
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
new_df.corr(method='pearson')
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# ...

# %%
old_df.corr(method='kendall')
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.099609  0.470873  -0.170677    0.003885 -0.025733
# HouseAge    -0.099609  1.000000 -0.157219  -0.082004   -0.197112 -0.016475
# AveRooms     0.470873 -0.157219  1.000000   0.055218   -0.072516  0.018495
# AveBedrms   -0.170677 -0.082004  0.055218   1.000000    0.020396 -0.088062
# Population   0.003885 -0.197112 -0.072516   0.020396    1.000000  0.164131
# AveOccup    -0.025733 -0.016475  0.018495  -0.088062    0.164131  1.000000
# Latitude    -0.059947  0.026044  0.084683   0.031485   -0.082507 -0.102363
# Longitude   -0.006248 -0.104427 -0.029806   0.006993    0.082974  0.121651
# MedHouseVal  0.495528  0.049822  0.179175  -0.083489    0.002172 -0.174370
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.059947  -0.006248     0.495528
# HouseAge     0.026044  -0.104427     0.049822
# AveRooms     0.084683  -0.029806     0.179175
# ...

# %%
new_df.corr(method='kendall')
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.099609  0.470873  -0.170677    0.003885 -0.025733
# HouseAge    -0.099609  1.000000 -0.157219  -0.082004   -0.197112 -0.016475
# AveRooms     0.470873 -0.157219  1.000000   0.055218   -0.072516  0.018495
# AveBedrms   -0.170677 -0.082004  0.055218   1.000000    0.020396 -0.088062
# Population   0.003885 -0.197112 -0.072516   0.020396    1.000000  0.164131
# AveOccup    -0.025733 -0.016475  0.018495  -0.088062    0.164131  1.000000
# Latitude    -0.059947  0.026044  0.084683   0.031485   -0.082507 -0.102363
# Longitude   -0.006248 -0.104427 -0.029806   0.006993    0.082974  0.121651
# MedHouseVal  0.495528  0.049822  0.179175  -0.083489    0.002172 -0.174370
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.059947  -0.006248     0.495528
# HouseAge     0.026044  -0.104427     0.049822
# AveRooms     0.084683  -0.029806     0.179175
# ...

# %%
old_df.corr(method='spearman')
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.147308  0.643671  -0.252426    0.006268 -0.044171
# HouseAge    -0.147308  1.000000 -0.231409  -0.120981   -0.283879 -0.024833
# AveRooms     0.643671 -0.231409  1.000000   0.082046   -0.105385  0.018807
# AveBedrms   -0.252426 -0.120981  0.082046   1.000000    0.027027 -0.132315
# Population   0.006268 -0.283879 -0.105385   0.027027    1.000000  0.242337
# AveOccup    -0.044171 -0.024833  0.018807  -0.132315    0.242337  1.000000
# Latitude    -0.088029  0.032440  0.127134   0.047197   -0.123626 -0.150954
# Longitude   -0.009928 -0.150752 -0.044783   0.010884    0.123527  0.181468
# MedHouseVal  0.676778  0.074855  0.263367  -0.125187    0.003839 -0.256594
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.088029  -0.009928     0.676778
# HouseAge     0.032440  -0.150752     0.074855
# AveRooms     0.127134  -0.044783     0.263367
# ...

# %%
new_df.corr(method='spearman')
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.147308  0.643671  -0.252426    0.006268 -0.044171
# HouseAge    -0.147308  1.000000 -0.231409  -0.120981   -0.283879 -0.024833
# AveRooms     0.643671 -0.231409  1.000000   0.082046   -0.105385  0.018807
# AveBedrms   -0.252426 -0.120981  0.082046   1.000000    0.027027 -0.132315
# Population   0.006268 -0.283879 -0.105385   0.027027    1.000000  0.242337
# AveOccup    -0.044171 -0.024833  0.018807  -0.132315    0.242337  1.000000
# Latitude    -0.088029  0.032440  0.127134   0.047197   -0.123626 -0.150954
# Longitude   -0.009928 -0.150752 -0.044783   0.010884    0.123527  0.181468
# MedHouseVal  0.676778  0.074855  0.263367  -0.125187    0.003839 -0.256594
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.088029  -0.009928     0.676778
# HouseAge     0.032440  -0.150752     0.074855
# AveRooms     0.127134  -0.044783     0.263367
# ...

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
new_df = pd.concat([df, target], axis=1)
new_df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
new_df[['AveRooms','MedHouseVal']].corr(method='pearson')
# Out:
#              AveRooms  MedHouseVal
# AveRooms     1.000000     0.151948
# MedHouseVal  0.151948     1.000000

# %%
new_df[['AveRooms','MedHouseVal']].corr(method='kendall')
# Out:
#              AveRooms  MedHouseVal
# AveRooms     1.000000     0.179175
# MedHouseVal  0.179175     1.000000

# %%
new_df[['AveRooms','MedHouseVal']].corr(method='spearman')
# Out:
#              AveRooms  MedHouseVal
# AveRooms     1.000000     0.263367
# MedHouseVal  0.263367     1.000000

# %%
sns.histplot(df.AveRooms, bins=100)
# Out:
# <AxesSubplot:xlabel='AveRooms', ylabel='Count'>

# %%
sns.histplot(df.AveRooms.loc[df.AveRooms < 20], bins=100)
# Out:
# <AxesSubplot:xlabel='AveRooms', ylabel='Count'>

# %%
df.AveRooms.describe()
# Out:
# count    20640.000000
# mean         5.429000
# std          2.474173
# min          0.846154
# 25%          4.440716
# 50%          5.229129
# 75%          6.052381
# max        141.909091
# Name: AveRooms, dtype: float64

# %%
plt.scatter(df.AveRooms, target)

# %%
new_df[['AveRooms','MedHouseVal']]
# Out:
#        AveRooms  MedHouseVal
# 0      6.984127        4.526
# 1      6.238137        3.585
# 2      8.288136        3.521
# 3      5.817352        3.413
# 4      6.281853        3.422
# ...         ...          ...
# 20635  5.045455        0.781
# 20636  6.114035        0.771
# 20637  5.205543        0.923
# 20638  5.329513        0.847
# 20639  5.254717        0.894
#
# [20640 rows x 2 columns]

# %%
q_025 = new_df.AveRooms.quantile(q=0.025)

# %%
q_975 = new_df.AveRooms.quantile(q=0.975)

# %%
rooms_df = new_df[['AveRooms','MedHouseVal']]

# %%
rooms_df = rooms_df[(rooms_df.AveRooms > q_025) & (rooms_df.AveRooms < q_975)]

# %%
rooms_df.describe()
# Out:
#            AveRooms   MedHouseVal
# count  19608.000000  19608.000000
# mean       5.292045      2.051720
# std        1.086507      1.135288
# min        3.076433      0.149990
# 25%        4.486435      1.188000
# 50%        5.229129      1.793000
# 75%        6.000000      2.633000
# max        8.344444      5.000010

# %%
rooms_df.corr(method='spearman')
# Out:
#              AveRooms  MedHouseVal
# AveRooms     1.000000     0.274793
# MedHouseVal  0.274793     1.000000

# %%
rooms_df.corr(method='kendall')
# Out:
#              AveRooms  MedHouseVal
# AveRooms     1.000000     0.186279
# MedHouseVal  0.186279     1.000000

# %%
rooms_df.corr(method='pearson')
# Out:
#              AveRooms  MedHouseVal
# AveRooms     1.000000     0.327759
# MedHouseVal  0.327759     1.000000

# %%
new_df = pd.concat([df, target], axis=1)
sns.heatmap(new_df.corr(method='pearson'), vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>
