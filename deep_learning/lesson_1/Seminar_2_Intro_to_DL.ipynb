# %% [markdown]
# # Оптимизация нейронных сетей. Метод обратного распространения ошибки (ноутбук)
#
# > Узнаем как устроена оптимизация нейронных сетей. Оптимизация в `PyTorch`.

# %% [markdown]
# ## План ноутбука
#
# 1. Высокоуровневое API для обучение нейросетей в `PyTorch`
# 2. Обучение первой нейросети в `PyTorch`

# %% [markdown]
# ## Высокоуровневое API для обучение нейросетей в `PyTorch`

# %%
import torch
import torch.nn as nn

# %% [markdown]
# ### Создание объекта нейросети

# %%
net = nn.Sequential(
    nn.Linear(700, 500),
    nn.ReLU(),
    nn.Linear(500, 200),
    nn.ReLU(),
    nn.Linear(200, 10)
)

# %%
net
# Out:
# Sequential(
#   (0): Linear(in_features=700, out_features=500, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=500, out_features=200, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=200, out_features=10, bias=True)
# )

# %%
from collections import OrderedDict

net = nn.Sequential(
    OrderedDict(
        [
            ('linear1', nn.Linear(700, 500)),
            ('relu1', nn.ReLU()),
            ('linear2', nn.Linear(500, 200)),
            ('relu2', nn.ReLU()),
            ('linear3', nn.Linear(200, 10))
        ]
    )
)

# %%
net.linear1
# Out:
# Linear(in_features=700, out_features=500, bias=True)

# %%
input_tensor = torch.rand(10, 700)

net(input_tensor).shape
# Out:
# torch.Size([10, 10])

# %%
class CustomTaskNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        self.linear1 = nn.Linear(700, 500)
        self.linear2 = nn.Linear(500, 200)
        self.linear3 = nn.Linear(200, 10)

        self.activation = nn.ReLU()

    def forward(self, x):
        output = self.activation(self.linear1(x))
        output = self.activation(self.linear2(output))
        output = self.linear3(output)

        return output

# %%
net = CustomTaskNetwork()

net(input_tensor).shape
# Out:
# torch.Size([10, 10])

# %%
net.to()
# Out:
# CustomTaskNetwork(
#   (linear1): Linear(in_features=700, out_features=500, bias=True)
#   (linear2): Linear(in_features=500, out_features=200, bias=True)
#   (linear3): Linear(in_features=200, out_features=10, bias=True)
#   (activation): ReLU()
# )

# %%
net.train()
net.eval()

net.requires_grad_()
# Out:
# CustomTaskNetwork(
#   (linear1): Linear(in_features=700, out_features=500, bias=True)
#   (linear2): Linear(in_features=500, out_features=200, bias=True)
#   (linear3): Linear(in_features=200, out_features=10, bias=True)
#   (activation): ReLU()
# )

# %%
net.parameters()
# Out:
# <generator object Module.parameters at 0x10a389510>

# %%
net.state_dict()
# Out:
# OrderedDict([('linear1.weight',
#               tensor([[ 0.0112,  0.0236,  0.0019,  ..., -0.0336, -0.0078, -0.0085],
#                       [-0.0313, -0.0248,  0.0001,  ...,  0.0007, -0.0306,  0.0245],
#                       [-0.0328, -0.0215, -0.0126,  ...,  0.0035,  0.0098,  0.0339],
#                       ...,
#                       [ 0.0306,  0.0347,  0.0028,  ...,  0.0022, -0.0008, -0.0056],
#                       [-0.0140,  0.0285, -0.0127,  ...,  0.0286, -0.0233, -0.0319],
#                       [ 0.0174,  0.0358, -0.0246,  ...,  0.0348, -0.0128, -0.0261]])),
#              ('linear1.bias',
#               tensor([ 2.9754e-02, -1.3126e-02,  1.4787e-02,  3.6148e-02, -1.1134e-02,
#                        2.4818e-02, -1.9866e-02, -2.4699e-02, -6.3364e-04, -2.5510e-02,
#                       -5.2723e-03,  2.7826e-03, -3.2614e-02, -3.5255e-02,  1.3799e-02,
#                       -1.7808e-02,  4.0862e-02, -3.1261e-02,  1.5785e-02,  4.5038e-03,
#                        3.9697e-02, -1.6904e-02,  1.3259e-02,  1.7671e-02,  1.4104e-02,
#                        4.4656e-02, -3.8434e-02,  3.3723e-02,  1.9677e-02, -3.7044e-02,
#                       -1.1819e-02,  1.5927e-02, -3.0031e-02,  3.7422e-02,  2.1415e-02,
#                       -2.1939e-02, -1.8508e-03, -1.7783e-03, -2.9039e-03, -1.3817e-02,
#                        2.1873e-02, -3.2451e-02,  1.5272e-02, -3.3312e-02,  2.1667e-02,
#                        2.4674e-02, -5.2070e-03, -3.3768e-02, -3.9512e-02,  4.0193e-02,
#                       -4.2534e-02, -2.1317e-02, -3.9007e-02, -1.4602e-02,  1.4416e-02,
#                       -3.2681e-02, -2.3684e-02,  4.2673e-02,  3.9370e-02, -1.9327e-02,
#                       -2.0135e-02, -3.8543e-02, -2.5655e-02,  4.4704e-02,  3.7098e-02,
#                       -6.7091e-03,  9.4667e-03,  2.3721e-02, -2.1993e-02,  1.5135e-03,
#                       -2.0930e-02,  4.2775e-02,  2.3555e-02,  2.3537e-02,  2.2001e-02])),
#              ('linear3.weight',
#               tensor([[ 0.0601,  0.0207,  0.0608,  ...,  0.0122, -0.0423,  0.0246],
#                       [-0.0017,  0.0617, -0.0553,  ..., -0.0559, -0.0085,  0.0488],
#                       [ 0.0066, -0.0380, -0.0372,  ...,  0.0157, -0.0597, -0.0135],
#                       ...,
#                       [-0.0263,  0.0504,  0.0062,  ...,  0.0147, -0.0195, -0.0694],
#                       [ 0.0227, -0.0697,  0.0687,  ...,  0.0655,  0.0616,  0.0443],
#                       [-0.0160, -0.0006,  0.0553,  ..., -0.0391,  0.0608,  0.0129]])),
#              ('linear3.bias',
#               tensor([ 0.0302,  0.0580,  0.0009,  0.0109,  0.0600,  0.0637, -0.0041, -0.0295,
#                        0.0236, -0.0542]))])

# %%
net.load_state_dict(net.state_dict())
# Out:
# <All keys matched successfully>

# %% [markdown]
# ### Оптимизаторы

# %%
from torch import optim

# %%
optim.SGD, optim.Adam
# Out:
# (torch.optim.sgd.SGD, torch.optim.adam.Adam)

# %%
optimizer = optim.Adam(net.parameters(), lr=0.0001)

# %%
optimizer
# Out:
# Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0001
#     maximize: False
#     weight_decay: 0
# )

# %%
optimizer = optim.SGD(
    [
        {'params': net.linear1.parameters()},
        {'params': net.linear2.parameters(), 'lr': 1e-3}
    ],
    lr=1e-2,
    momentum=0.9
)

# %%
optimizer.step()

# %%
optimizer.zero_grad()

# %% [markdown]
# ### Функции потерь

# %%
nn.L1Loss, nn.MSELoss, nn.CrossEntropyLoss
# Out:
# (torch.nn.modules.loss.L1Loss,
#  torch.nn.modules.loss.MSELoss,
#  torch.nn.modules.loss.CrossEntropyLoss)

# %%
loss = nn.MSELoss()

# %%
input = torch.randn(3, 5, requires_grad=True)
target = torch.randn(3, 5)

output = loss(input, target)

print(output)

output.backward()
# Out:
# tensor(1.9623, grad_fn=<MseLossBackward0>)

# %%
input.grad
# Out:
# tensor([[-0.1863,  0.0963, -0.3480,  0.0311, -0.0168],
#         [-0.1721,  0.1640, -0.2355, -0.1563, -0.1045],
#         [-0.2076,  0.0515, -0.2527,  0.0228, -0.3155]])

# %% [markdown]
# ### Датасеты и даталоадеры

# %%
from torch.utils.data import Dataset
from torch.utils.data import TensorDataset

# %%
n_features = 2
n_objects = 300

torch.manual_seed(0);

# %%
w_true = torch.randn(n_features)

X = (torch.rand(n_objects, n_features) - 0.5) * 10
X *= (torch.arange(n_features) * 2 + 1)
Y = (X @ w_true + torch.randn(n_objects)).unsqueeze(1)

# %%
dataset = TensorDataset(X, Y)

# %%
dataset[7]
# Out:
# (tensor([-3.3897, -6.5319]), tensor([-3.7483]))

# %%
X[7], Y[7]
# Out:
# (tensor([-3.3897, -6.5319]), tensor([-3.7483]))

# %%
class CustomDataset(Dataset):
    def __init__(self, w_true, n_features, n_objects):
        self.X = (torch.rand(n_objects, n_features) - 0.5) * 10
        self.X *= (torch.arange(n_features) * 2 + 1)
        self.Y = self.X @ w_true + torch.randn(n_objects)

    def __len__(self):
        return len(self.Y)

    def __getitem__(self, item):
        return self.X[item], self.Y[item]

# %%
dataset = CustomDataset(w_true, n_features, n_objects)

# %%
from torch.utils.data import DataLoader

# %%
loader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
for x, y in loader:
    print(x.shape)
# Out:
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])
# torch.Size([4, 2])

# %%
X.shape
# Out:
# torch.Size([300, 2])

# %% [markdown]
# ### Общая структура обучения модели

# %%
model.train()

for x, y in dataloader:

    optimizer.zero_grad()

    output = model(x)

    loss = loss_fn(output, y)

    loss.backward()

    optimizer.step()

# %% [markdown]
# ## Обучение первой нейросети в `PyTorch`

# %%
class CustomTaskNetwork(nn.Module):
    def __init__(self):
        super().__init__()

        self.linear = nn.Linear(n_features, 1)

    def forward(self, x):
        return self.linear(x)

net = CustomTaskNetwork()

optimizer = optim.Adam(net.parameters(), lr=1e-1)

loss_fn = nn.MSELoss()

dataset = TensorDataset(X, Y)

loader = DataLoader(dataset, batch_size=4, shuffle=True)

w_list = torch.empty(len(loader) + 1, n_features)

# %%
net.train()

for i, (x, y) in enumerate(loader):
    w_list[i] = net.linear.weight.detach().clone()

    optimizer.zero_grad()

    output = net(x)

    loss = loss_fn(output, y)

    print(f'MSE на шаге {i} {loss.item():.5f}')

    loss.backward()

    optimizer.step()

w_list[len(loader)] = net.linear.weight.detach().clone()
# Out:
# MSE на шаге 0 26.19419
# MSE на шаге 1 21.36962
# MSE на шаге 2 72.87616
# MSE на шаге 3 60.03906
# MSE на шаге 4 8.88771
# MSE на шаге 5 30.41561
# MSE на шаге 6 9.93647
# MSE на шаге 7 8.02992
# MSE на шаге 8 18.51692
# MSE на шаге 9 3.50421
# MSE на шаге 10 6.23041
# MSE на шаге 11 5.03649
# MSE на шаге 12 2.36526
# MSE на шаге 13 9.67055
# MSE на шаге 14 1.16297
# MSE на шаге 15 0.65199
# MSE на шаге 16 6.95910
# MSE на шаге 17 1.41618
# MSE на шаге 18 2.11158
# MSE на шаге 19 4.88758
# MSE на шаге 20 12.11743
# MSE на шаге 21 6.28058
# MSE на шаге 22 3.83081
# MSE на шаге 23 4.83289
# MSE на шаге 24 3.57723
# MSE на шаге 25 5.58337
# MSE на шаге 26 0.83595
# MSE на шаге 27 1.14049
# MSE на шаге 28 0.83483
# MSE на шаге 29 1.73279
# MSE на шаге 30 5.10439
# MSE на шаге 31 0.95391
# MSE на шаге 32 1.75330
# MSE на шаге 33 1.10862
# MSE на шаге 34 1.73119
# MSE на шаге 35 0.33786
# MSE на шаге 36 6.48447
# MSE на шаге 37 2.83668
# MSE на шаге 38 2.39993
# MSE на шаге 39 0.66318
# MSE на шаге 40 2.13568
# MSE на шаге 41 1.04859
# MSE на шаге 42 0.81732
# MSE на шаге 43 2.23174
# MSE на шаге 44 1.04640
# MSE на шаге 45 1.33302
# MSE на шаге 46 0.55039
# MSE на шаге 47 3.06279
# MSE на шаге 48 0.73858
# MSE на шаге 49 0.41384
# MSE на шаге 50 2.33726
# MSE на шаге 51 0.65000
# MSE на шаге 52 0.53509
# MSE на шаге 53 1.54348
# MSE на шаге 54 0.52052
# MSE на шаге 55 1.12599
# MSE на шаге 56 1.09426
# MSE на шаге 57 0.82292
# MSE на шаге 58 0.58171
# MSE на шаге 59 0.85434
# MSE на шаге 60 1.14722
# MSE на шаге 61 0.61926
# MSE на шаге 62 0.53796
# MSE на шаге 63 0.90856
# MSE на шаге 64 0.40359
# MSE на шаге 65 1.20112
# MSE на шаге 66 1.38641
# MSE на шаге 67 0.25120
# MSE на шаге 68 0.92327
# MSE на шаге 69 0.72409
# MSE на шаге 70 0.88464
# MSE на шаге 71 0.81584
# MSE на шаге 72 0.78073
# MSE на шаге 73 1.74414
# MSE на шаге 74 1.29557

# %%
from plot_trajectory import plot_trajectory

plot_trajectory(
    w_list.numpy(),
    w_true.numpy(),
    X.numpy(),
    Y.squeeze(1).numpy(),
    'Mini-batch градиентный спуск'
)
# Out:
# <div>                            <div id="88d1286d-2ab9-42f8-885b-b2afa548ed7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("88d1286d-2ab9-42f8-885b-b2afa548ed7a")) {                    Plotly.newPlot(                        "88d1286d-2ab9-42f8-885b-b2afa548ed7a",                        [{"contours":{"coloring":"lines"},"line":{"smoothing":1,"width":2},"name":"Loss function levels","ncontours":100,"opacity":0.5,"x":[0.1622410297393797,0.19009466701083697,0.21794830428229423,0.24580194155375146,0.27365557882520875,0.301509216096666,0.3293628533681232,0.3572164906395805,0.38507012791103773,0.41292376518249496,0.44077740245395225,0.4686310397254095,0.4964846769968667,0.524338314268324,0.5521919515397813,0.5800455888112386,0.6078992260826958,0.6357528633541529,0.6636065006256102,0.6914601378970675,0.7193137751685248,0.747167412439982,0.7750210497114393,0.8028746869828965,0.8307283242543537,0.858581961525811,0.8864355987972683,0.9142892360687256,0.9421428733401828,0.96999651061164,0.9978501478830973,1.0257037851545545,1.0535574224260118,1.081411059697469,1.1092646969689262,1.1371183342403834,1.1649719715118407,1.192825608783298,1.2206792460547553,1.2485328833262126,1.2763865205976699,1.3042401578691272,1.3320937951405842,1.3599474324120415,1.3878010696834988,1.415654706954956,1.4435083442264134,1.4713619814978707,1.4992156187693277,1.527069256040785,1.5549228933122423,1.5827765305836996,1.610630167855157,1.6384838051266142,1.6663374423980715,1.6941910796695285,1.7220447169409858,1.749898354212443,1.7777519914839004,1.8056056287553577,1.833459266026815,1.861312903298272,1.8891665405697293,1.9170201778411866,1.944873815112644,1.9727274523841012,2.0005810896555585,2.0284347269270158,2.0562883641984726,2.08414200146993,2.111995638741387,2.1398492760128445,2.1677029132843018,2.195556550555759,2.2234101878272163,2.2512638250986736,2.279117462370131,2.306971099641588,2.3348247369130455,2.3626783741845028,2.39053201145596,2.4183856487274173,2.4462392859988746,2.474092923270332,2.5019465605417888,2.529800197813246,2.5576538350847033,2.5855074723561606,2.613361109627618,2.641214746899075,2.6690683841705325,2.69692202144199,2.724775658713447,2.7526292959849044,2.7804829332563616,2.808336570527819,2.8361902077992758,2.864043845070733,2.8918974823421904,2.9197511196136476],"y":[-1.278504079580307,-1.2586035708586376,-1.2387030621369681,-1.2188025534152986,-1.198902044693629,-1.1790015359719594,-1.15910102725029,-1.1392005185286205,-1.119300009806951,-1.0993995010852815,-1.079498992363612,-1.0595984836419423,-1.0396979749202728,-1.0197974661986033,-0.9998969574769339,-0.9799964487552644,-0.9600959400335949,-0.9401954313119253,-0.9202949225902558,-0.9003944138685862,-0.8804939051469167,-0.8605933964252472,-0.8406928877035778,-0.8207923789819083,-0.8008918702602387,-0.7809913615385692,-0.7610908528168997,-0.7411903440952301,-0.7212898353735606,-0.7013893266518911,-0.6814888179302216,-0.661588309208552,-0.6416878004868826,-0.6217872917652131,-0.6018867830435435,-0.581986274321874,-0.5620857656002045,-0.542185256878535,-0.5222847481568654,-0.502384239435196,-0.48248373071352646,-0.46258322199185686,-0.4426827132701874,-0.4227822045485179,-0.4028816958268484,-0.3829811871051788,-0.3630806783835093,-0.34318016966183984,-0.32327966094017024,-0.30337915221850076,-0.2834786434968313,-0.2635781347751618,-0.2436776260534923,-0.22377711733182282,-0.2038766086101531,-0.18397609988848362,-0.16407559116681414,-0.14417508244514465,-0.12427457372347517,-0.10437406500180568,-0.0844735562801362,-0.06457304755846649,-0.044672538836797004,-0.02477203011512752,-0.004871521393458034,0.015028987328211452,0.03492949604988094,0.05483000477155042,0.07473051349322013,0.09463102221488962,0.1145315309365591,0.13443203965822859,0.15433254 ...

# %%
num_epochs = 5

w_list = torch.empty(len(loader) * num_epochs + 1, n_features)

net = CustomTaskNetwork()

optimizer = optim.Adam(net.parameters(), lr=1e-1)

# %%
net.train()

for epoch in range(num_epochs):
    total_loss = 0

    for i, (x, y) in enumerate(loader):
        w_list[i + epoch * len(loader)] = net.linear.weight.detach().clone()

        optimizer.zero_grad()

        output = net(x)

        loss = loss_fn(output, y)

        total_loss += loss.item()

        loss.backward()

        optimizer.step()

    total_loss /= len(loader)

    print(f'MSE после эпохи {epoch} {total_loss:.5f}')

w_list[len(loader) * num_epochs] = net.linear.weight.detach().clone()
# Out:
# MSE после эпохи 0 3.36680
# MSE после эпохи 1 1.11715
# MSE после эпохи 2 1.12583
# MSE после эпохи 3 1.26559
# MSE после эпохи 4 1.11840

# %%
from plot_trajectory import plot_trajectory

plot_trajectory(
    w_list.numpy(),
    w_true.numpy(),
    X.numpy(),
    Y.squeeze(1).numpy(),
    'Mini-batch градиентный спуск'
)
# Out:
# <div>                            <div id="17bb33ff-b045-42ff-ba25-7036e5e23378" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("